# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv('D:/Leads.csv')

# %%
df.head(10)
# Out:
#                             Prospect ID  Lead Number              Lead Origin  \
# 0  7927b2df-8bba-4d29-b9a2-b6e0beafe620       660737                      API
# 1  2a272436-5132-4136-86fa-dcc88c88f482       660728                      API
# 2  8cc8c611-a219-4f35-ad23-fdfd2656bd8a       660727  Landing Page Submission
# 3  0cc2df48-7cf4-4e39-9de9-19797f9b38cc       660719  Landing Page Submission
# 4  3256f628-e534-4826-9d63-4a8b88782852       660681  Landing Page Submission
# 5  2058ef08-2858-443e-a01f-a9237db2f5ce       660680                      API
# 6  9fae7df4-169d-489b-afe4-0f3d752542ed       660673  Landing Page Submission
# 7  20ef72a2-fb3b-45e0-924e-551c5fa59095       660664                      API
# 8  cfa0128c-a0da-4656-9d47-0aa4e67bf690       660624  Landing Page Submission
# 9  af465dfc-7204-4130-9e05-33231863c4b5       660616                      API
#
#       Lead Source Do Not Email Do Not Call  Converted  TotalVisits  \
# ...

# %%
# dropping these 2 first because these 2 variables are of no use
df = df.drop(['Prospect ID', 'Lead Number'], axis=1)

# %%
df.head(10)
# Out:
#                Lead Origin     Lead Source Do Not Email Do Not Call  \
# 0                      API      Olark Chat           No          No
# 1                      API  Organic Search           No          No
# 2  Landing Page Submission  Direct Traffic           No          No
# 3  Landing Page Submission  Direct Traffic           No          No
# 4  Landing Page Submission          Google           No          No
# 5                      API      Olark Chat           No          No
# 6  Landing Page Submission          Google           No          No
# 7                      API      Olark Chat           No          No
# 8  Landing Page Submission  Direct Traffic           No          No
# 9                      API          Google           No          No
#
#    Converted  TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0          0          0.0                            0                   0.0
# ...

# %%
# checking the null values
df.isnull().sum()
# Out:
# Lead Origin                                         0
# Lead Source                                        36
# Do Not Email                                        0
# Do Not Call                                         0
# Converted                                           0
# TotalVisits                                       137
# Total Time Spent on Website                         0
# Page Views Per Visit                              137
# Last Activity                                     103
# Country                                          2461
# Specialization                                   1438
# How did you hear about X Education               2207
# What is your current occupation                  2690
# What matters most to you in choosing a course    2709
# Search                                              0
# Magazine                                            0
# Newspaper Article                                   0
# ...

# %%
# Drop rows with any null values
df = df.dropna()

# %%
df.isnull().sum()
# Out:
# Lead Origin                                      0
# Lead Source                                      0
# Do Not Email                                     0
# Do Not Call                                      0
# Converted                                        0
# TotalVisits                                      0
# Total Time Spent on Website                      0
# Page Views Per Visit                             0
# Last Activity                                    0
# Country                                          0
# Specialization                                   0
# How did you hear about X Education               0
# What is your current occupation                  0
# What matters most to you in choosing a course    0
# Search                                           0
# Magazine                                         0
# Newspaper Article                                0
# X Education Forums                               0
# ...

# %%
# converting the categorical values in appropriate numbers
 import pandas as pd
from sklearn.preprocessing import LabelEncoder
# Fill NaNs with appropriate values or drop them
df['Country'].fillna('Unknown', inplace=True)
df['City'].fillna('Unknown', inplace=True)
df['Lead Profile'].fillna('Unknown', inplace=True)

# List of categorical columns to encode
categorical_columns = ['Lead Origin', 'Lead Source', 'Do Not Email', 'Do Not Call',
       'TotalVisits', 'Total Time Spent on Website', 'Page Views Per Visit',
       'Last Activity', 'Country', 'Specialization',
       'How did you hear about X Education', 'What is your current occupation',
       'What matters most to you in choosing a course', 'Search', 'Magazine',
       'Newspaper Article', 'X Education Forums', 'Newspaper',
       'Digital Advertisement', 'Through Recommendations',
       'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
       'Update me on Supply Chain Content', 'Get updates on DM Content',
       'Lead Profile', 'City', 'Asymmetrique Activity Index',
       'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
       'Asymmetrique Profile Score',
       'I agree to pay the amount through cheque',
       'A free copy of Mastering The Interview', 'Last Notable Activity',
       'Converted']

# Initialize the LabelEncoder
le = LabelEncoder()

# Apply Label Encoding to each categorical column
for column in categorical_columns:
    df[column] = le.fit_transform(df[column].astype(str))

# Verify the transformation
print(df.head())
# Out:
#    Lead Origin  Lead Source  Do Not Email  Do Not Call  Converted  \
# 0            0           18             0            0          0
# 1            0           19             0            0          0
# 2            1            1             0            0          1
# 3            1            1             0            0          0
# 4            1           15             0            0          1
#
#    TotalVisits  Total Time Spent on Website  Page Views Per Visit  \
# 0            0                            0                     0
# 1           27                          463                    68
# 2            6                         1256                    53
# 3            1                           42                     1
# 4            6                         1137                     1
#
#    Last Activity  Country  ...  Get updates on DM Content  Lead Profile  City  \
# 0              2       30  ...                          0             4     4
# ...

# %%
# checking the correlation
correlation_matrix = df.corr()
plt.figure(figsize=(20, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix Heatmap")
plt.show()

# %%
# Since converted is our target variable, we are dropping it from x
X = df.drop('Converted', axis=1)
y = df['Converted']

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Number of columns (variables) in the DataFrame
num_variables = len(df.columns)
print(f"Number of variables in the dataset: {num_variables}")
# Out:
# Number of variables in the dataset: 35

# %%
correlation_matrix = df.corr()

# Extract the correlation values with the target variable 'Converted'
correlation_with_target = correlation_matrix['Converted']

# Sort the correlations in descending order (most positively correlated at the top)
sorted_correlation = correlation_with_target.sort_values(ascending=False)

# Select the top 15 most correlated variables (excluding 'Converted' itself)
top_15_variables = sorted_correlation[1:16]  

# Print the top 15 variables
print("Top 15 Variables Most Correlated with 'Converted':")
print(top_15_variables)
# Out:
# Top 15 Variables Most Correlated with 'Converted':
# How did you hear about X Education    0.255042
# Lead Origin                           0.223725
# Asymmetrique Profile Score            0.073574
# Asymmetrique Activity Score           0.067268
# TotalVisits                           0.058720
# Country                               0.053949
# Total Time Spent on Website           0.044490
# Through Recommendations               0.018607
# Do Not Call                           0.018581
# Page Views Per Visit                  0.004819
# Asymmetrique Activity Index           0.003994
# Newspaper Article                     0.003465
# Search                               -0.002261
# Digital Advertisement                -0.005789
# Newspaper                            -0.008238
# Name: Converted, dtype: float64

# %%
correlation_matrix = df.corr()

# Extract the correlation values with the target variable 'Converted'
correlation_with_target = correlation_matrix['Converted']

# Sort the correlations in descending order and select the top 15 most correlated variables
top_15_variables = correlation_with_target.sort_values(ascending=False)[1:16]

# List of top 15 variable names (plus 'Converted')
top_15_variable_names = top_15_variables.index.tolist() + ['Converted']

# Filter the DataFrame to keep only the top 15 variables plus the target variable 'Converted'
df_top_15 = df[top_15_variable_names]

# Display the resulting DataFrame with only the top 15 variables
print("Dataset with Top 15 Variables:")
print(df_top_15.head())
# Out:
# Dataset with Top 15 Variables:
#    How did you hear about X Education  Lead Origin  \
# 0                                   7            0
# 1                                   7            0
# 2                                   7            1
# 3                                  10            1
# 4                                   5            1
#
#    Asymmetrique Profile Score  Asymmetrique Activity Score  TotalVisits  \
# 0                           5                            8            0
# 1                           5                            8           27
# 2                          10                            7            6
# 3                           7                            6            1
# 4                           8                            8            6
#
#    Country  Total Time Spent on Website  Through Recommendations  Do Not Call  \
# 0       30                            0                        0            0
# ...

# %%
# lets try our model1 = Logistic Regression

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression

from sklearn.metrics import accuracy_score, classification_report, confusion_matrix

# %%
# Standardize the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Build and train the logistic regression model
model1 = LogisticRegression()
model1.fit(X_train_scaled, y_train)

# Make predictions
y_pred = model1.predict(X_test_scaled)

# Evaluate the model
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))
print("\nClassification Report:")
# Out:
# Confusion Matrix:
# [[1492  203]
#  [ 338  739]]
#
# Classification Report:

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
print(accuracy)
# Out:
# 0.8048340548340548

# %%
# so our modelis 80% accurate

# %%
# Initialize and train the Logistic Regression model
log_reg = LogisticRegression(random_state=42)
log_reg.fit(X_train, y_train)

# Get the coefficients of the logistic regression model
coefficients = log_reg.coef_[0]

# Create a DataFrame to view feature importances
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Coefficient': coefficients})

# Sort features by the absolute value of their coefficients
sorted_features = feature_importance_df.reindex(feature_importance_df.Coefficient.abs().sort_values(ascending=False).index)

# Print top 3 features
top_3_features = sorted_features.head(3)
print("Top 3 Features Contributing to Conversion Probability:")
print(top_3_features)
# Out:
# Top 3 Features Contributing to Conversion Probability:
#                         Feature  Coefficient
# 22                 Lead Quality    -0.625324
# 29  Asymmetrique Activity Score     0.194636
# 25                 Lead Profile    -0.172845

# %%
# Print all feature names to inspect
print("Feature Names in the Dataset:")
print(X.columns)

# Filter all features (both numerical and categorical) by the absolute value of their coefficients
feature_importance_df = pd.DataFrame({'Feature': X.columns, 'Coefficient': coefficients})
sorted_features = feature_importance_df.reindex(feature_importance_df.Coefficient.abs().sort_values(ascending=False).index)

# Identify the top 3 overall features contributing to conversion
top_3_features = sorted_features.head(3)
print("Top 3 Features Contributing to Conversion Probability:")
print(top_3_features)

# If looking specifically for dummy variables (features with a specific pattern)
dummy_variables = sorted_features[sorted_features['Feature'].str.contains('_')]  # Adjust this if needed
top_3_dummies = dummy_variables.head(3)

print("Top 3 Categorical/Dummy Variables Contributing to Conversion Probability:")
print(top_3_dummies)
# Out:
# Feature Names in the Dataset:
# Index(['Lead Origin', 'Lead Source', 'Do Not Email', 'Do Not Call',
#        'TotalVisits', 'Total Time Spent on Website', 'Page Views Per Visit',
#        'Last Activity', 'Country', 'Specialization',
#        'How did you hear about X Education', 'What is your current occupation',
#        'What matters most to you in choosing a course', 'Search', 'Magazine',
#        'Newspaper Article', 'X Education Forums', 'Newspaper',
#        'Digital Advertisement', 'Through Recommendations',
#        'Receive More Updates About Our Courses', 'Tags', 'Lead Quality',
#        'Update me on Supply Chain Content', 'Get updates on DM Content',
#        'Lead Profile', 'City', 'Asymmetrique Activity Index',
#        'Asymmetrique Profile Index', 'Asymmetrique Activity Score',
#        'Asymmetrique Profile Score',
#        'I agree to pay the amount through cheque',
#        'A free copy of Mastering The Interview', 'Last Notable Activity'],
# ...
